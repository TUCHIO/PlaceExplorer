# %%
import json

from place_explorer import PlaceExplorer

# %%
with open("api_key.json", "rt") as f:
    api_key = json.load(f)

# %%
# 1st place
explorer = PlaceExplorer(
    39.00460959038751, # latitude 
    141.62485861939834, # longitude
    500, # radius in meter
    api_key["google_api_key"], # your google api key
    "rikuzen_takata.pickle", # file name to save status
    grid_size=10, # grid size in meter
)

# %%
explorer()

# %%
# 2nd place
explorer = PlaceExplorer(
    38.831437314573535, # latitude 
    141.5912069806865, # longitude
    500, # radius in meter
    api_key["google_api_key"], # your google api key
    "kesennuma.pickle", # file name to save status
    grid_size=10, # grid size in meter
)

# %%
explorer()

# %%
# 3rd place
explorer = PlaceExplorer(
    38.6783483579473, # latitude 
    141.44634396345887, # longitude
    500, # radius in meter
    api_key["google_api_key"], # your google api key
    "minami_sanriku.pickle", # file name to save status
    grid_size=10, # grid size in meter
)

# %%
explorer()

# %%
# 4th place
explorer = PlaceExplorer(
    38.44534305989525, # latitude 
    141.44700455581957, # longitude
    500, # radius in meter
    api_key["google_api_key"], # your google api key
    "onagawa.pickle", # file name to save status
    grid_size=10, # grid size in meter
)

# %%
explorer()

# %%
# 5th place
explorer = PlaceExplorer(
    38.5464996519776, # latitude 
    141.42764534790393, # longitude
    500, # radius in meter
    api_key["google_api_key"], # your google api key
    "ishinomaki_ookawa.pickle", # file name to save status
    grid_size=10, # grid size in meter
)

# %%
explorer()

# %%
# 6th place
explorer = PlaceExplorer(
    38.4220652145033, # latitude 
    141.30468434314247, # longitude
    500, # radius in meter
    api_key["google_api_key"], # your google api key
    "ishinomaki_kadonowaki.pickle", # file name to save status
    grid_size=10, # grid size in meter
)

# %%
explorer()

# %%
# 7th place
explorer = PlaceExplorer(
    38.375170909282815, # latitude 
    141.15990592883605, # longitude
    500, # radius in meter
    api_key["google_api_key"], # your google api key
    "higashi_matsushima.pickle", # file name to save status
    grid_size=10, # grid size in meter
)

# %%
explorer()

# %%
# 8th place
explorer = PlaceExplorer(
    38.22243183232661, # latitude 
    140.98072465581956, # longitude 
    500, # radius in meter
    api_key["google_api_key"], # your google api key
    "sendai_arahama.pickle", # file name to save status
    grid_size=10, # grid size in meter
)

# %%
explorer()

# %%
# dummy place to merge other pickles
explorer = PlaceExplorer(
    0, # latitude 
    0, # longitude
    0, # radius in meter
    api_key["google_api_key"], # your google api key
    "ruins.pickle", # file name to save status
    grid_size=10, # grid size in meter
)

# %%
# import previous results
explorer.import_result("rikuzen_takata.pickle")
explorer.import_result("kesennuma.pickle")
explorer.import_result("minami_sanriku.pickle")
explorer.import_result("onagawa.pickle")
explorer.import_result("ishinomaki_ookawa.pickle")
explorer.import_result("ishinomaki_kadonowaki.pickle")
explorer.import_result("higashi_matsushima.pickle") 
explorer.import_result("sendai_arahama.pickle")

# %%
explorer.export_csv("tohoku_ruins.csv")
